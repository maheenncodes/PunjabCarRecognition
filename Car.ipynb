# %%
# !pip install torch torchvision torchaudio --index-url https://download.pytorch.org/whl/cu121
# Out:
# Looking in indexes: https://download.pytorch.org/whl/cu121
# ...
# WARNING: You are using pip version 22.0.4; however, version 23.3.1 is available.
# You should consider upgrading via the 'C:\Users\hamiz\AppData\Local\Programs\Python\Python310\python.exe -m pip install --upgrade pip' command.

# %%
# !git clone https://github.com/ultralytics/yolov5
# Out:
# fatal: destination path 'yolov5' already exists and is not an empty directory.

# %%
# !git clone https://github.com/maheenncodes/PunjabCarsDataset
# Out:
# Cloning into 'PunjabCarsDataset'...

# %%
cd yolov5
# Out:
# C:\Users\hamiz\OneDrive\Desktop\Car\yolov5
# C:\Users\hamiz\AppData\Local\Programs\Python\Python310\lib\site-packages\IPython\core\magics\osm.py:417: UserWarning: using dhist requires you to install the `pickleshare` library.
#   self.shell.db['dhist'] = compress_dhist(dhist)[-100:]

# %%
# !pip install -r requirements.txt
# Out:
# ...
# WARNING: You are using pip version 22.0.4; however, version 23.3.1 is available.
# You should consider upgrading via the 'C:\Users\hamiz\AppData\Local\Programs\Python\Python310\python.exe -m pip install --upgrade pip' command.

# %%
import torch
from matplotlib import pyplot as plt
import numpy as np
import cv2

# %%
model = torch.hub.load('ultralytics/yolov5', 'yolov5s')
# Out:
# Using cache found in C:\Users\hamiz/.cache\torch\hub\ultralytics_yolov5_master
# YOLOv5  2023-11-19 Python-3.10.5 torch-2.1.1+cu121 CPU
#
# Fusing layers...
# YOLOv5s summary: 213 layers, 7225885 parameters, 0 gradients, 16.4 GFLOPs
# Adding AutoShape...

# %%
# !pip install --upgrade pillow
# Out:
# ...
# WARNING: You are using pip version 22.0.4; however, version 23.3.1 is available.
# You should consider upgrading via the 'C:\Users\hamiz\AppData\Local\Programs\Python\Python310\python.exe -m pip install --upgrade pip' command.

# %%
# !python C:\Users\hamiz\OneDrive\Desktop\Car\yolov5\train.py --img 320 --batch 16 --epochs 200 --data C:\Users\hamiz\OneDrive\Desktop\Car\yolov5\data.yaml --weights yolov5s.pt --workers 2

# %%
model = torch.hub.load('ultralytics/yolov5', 'custom', path='C:\\Users\\hamiz\\OneDrive\\Desktop\\Car\\yolov5\\runs\\train\\exp\\weights\\best.pt' , force_reload=True)
# Out:
# Downloading: "https://github.com/ultralytics/yolov5/zipball/master" to C:\Users\hamiz/.cache\torch\hub\master.zip
# YOLOv5  2023-11-19 Python-3.10.5 torch-2.1.1+cu121 CPU
#
# Fusing layers...
# Model summary: 157 layers, 7058671 parameters, 0 gradients, 15.9 GFLOPs
# Adding AutoShape...

# %%
# !python C:\Users\hamiz\OneDrive\Desktop\Car\yolov5\val.py --img 320 --batch-size 16 --data C:\Users\hamiz\OneDrive\Desktop\Car\yolov5\data.yaml --weights C:\Users\hamiz\OneDrive\Desktop\Car\yolov5\runs\train\exp\weights\best.pt
# Out:
# val: data=C:\Users\hamiz\OneDrive\Desktop\Car\yolov5\data.yaml, weights=['C:\\Users\\hamiz\\OneDrive\\Desktop\\Car\\yolov5\\runs\\train\\exp\\weights\\best.pt'], batch_size=16, imgsz=320, conf_thres=0.001, iou_thres=0.6, max_det=300, task=val, device=, workers=8, single_cls=False, augment=False, verbose=False, save_txt=False, save_hybrid=False, save_conf=False, save_json=False, project=yolov5\runs\val, name=exp, exist_ok=False, half=False, dnn=False
# YOLOv5  v7.0-241-gb6a65e1 Python-3.10.5 torch-2.1.1+cu121 CPU
#
# Fusing layers...
# Model summary: 157 layers, 7058671 parameters, 0 gradients, 15.9 GFLOPs
# Traceback (most recent call last):
#   File "C:\Users\hamiz\OneDrive\Desktop\Car\yolov5\utils\dataloaders.py", line 481, in __init__
#     assert self.im_files, f'{prefix}No images found'
# AssertionError: val: No images found
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
# ...

# %%
pip install opencv-python
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
# WARNING: You are using pip version 22.0.4; however, version 23.3.1 is available.
# You should consider upgrading via the 'C:\Users\hamiz\AppData\Local\Programs\Python\Python310\python.exe -m pip install --upgrade pip' command.

# %%
image_path = 'C:\\Users\\hamiz\\OneDrive\\Desktop\\Car\\yolov5\\PunjabCarsDataset\\data\\test\\images\\DSC_1002.JPG'

# %%
image = cv2.imread(image_path)
image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)

# %%
results = model(image)

# %%
results.print()
# Out:
# image 1/1: 993x1161 1 Not Punjab
# Speed: 104.3ms pre-process, 661.4ms inference, 116.1ms NMS per image at shape (1, 3, 576, 640)

# %%
# %matplotlib inline
plt.imshow(np.squeeze(results.render()))
plt.show()

# %%
image_path = 'C:\\Users\\hamiz\\OneDrive\\Desktop\\Car\\yolov5\\PunjabCarsDataset\\data\\test\\images\\DSC_1006.JPG'

# %%
image = cv2.imread(image_path)
image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)

# %%
results = model(image)

# %%
results.print()
# Out:
# image 1/1: 929x1329 2 Punjabs
# Speed: 42.4ms pre-process, 434.9ms inference, 2.2ms NMS per image at shape (1, 3, 448, 640)

# %%
# %matplotlib inline
plt.imshow(np.squeeze(results.render()))
plt.show()
