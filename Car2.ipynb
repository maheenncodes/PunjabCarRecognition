# %%
# !git clone https://github.com/maheenncodes/PunjabCarRecognition
# Out:
# Cloning into 'PunjabCarRecognition'...
# remote: Enumerating objects: 717, done.
# remote: Counting objects: 100% (8/8), done.
# remote: Compressing objects: 100% (5/5), done.
# remote: Total 717 (delta 2), reused 8 (delta 2), pack-reused 709
# Receiving objects: 100% (717/717), 101.35 MiB | 41.41 MiB/s, done.
# Resolving deltas: 100% (43/43), done.
# Updating files: 100% (664/664), done.

# %%
# !pip install torch torchvision torchaudio --index-url https://download.pytorch.org/whl/cu121
# Out:
# Looking in indexes: https://download.pytorch.org/whl/cu121
# ...

# %%
# !git clone https://github.com/ultralytics/yolov5

# %%
# !git clone https://github.com/maheenncodes/PunjabCarsDataset

# %%
# !pip install -r requirements.txt

# %%
import torch
from matplotlib import pyplot as plt
import numpy as np
import cv2

# %%
cd /content

# %%
model = torch.hub.load('ultralytics/yolov5', 'yolov5s')
# Out:
# /usr/local/lib/python3.10/dist-packages/torch/hub.py:294: UserWarning: You are about to download and run code from an untrusted repository. In a future release, this won't be allowed. To add the repository to your trusted list, change the command to {calling_fn}(..., trust_repo=False) and a command prompt will appear asking for an explicit confirmation of trust, or load(..., trust_repo=True), which will assume that the prompt is to be answered with 'yes'. You can also use load(..., trust_repo='check') which will only prompt for confirmation if the repo is not already trusted. This will eventually be the default behaviour
#   warnings.warn(
# Downloading: "https://github.com/ultralytics/yolov5/zipball/master" to /root/.cache/torch/hub/master.zip
# requirements: Ultralytics requirements ['gitpython>=3.1.30', 'Pillow>=10.0.1'] not found, attempting AutoUpdate...
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 190.6/190.6 kB 4.5 MB/s eta 0:00:00
# ...

# %%
# !pip install --upgrade pillow

# %%
# !pip install Pillow

# %%
# !python /content/yolov5/train.py --img 320 --batch 16 --epochs 200 --data /content/yolov5/data.yaml --weights yolov5s.pt
# Out:
# 2023-11-18 23:49:29.743753: E tensorflow/compiler/xla/stream_executor/cuda/cuda_dnn.cc:9342] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2023-11-18 23:49:29.743810: E tensorflow/compiler/xla/stream_executor/cuda/cuda_fft.cc:609] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2023-11-18 23:49:29.743851: E tensorflow/compiler/xla/stream_executor/cuda/cuda_blas.cc:1518] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# ...

# %%
model = torch.hub.load('ultralytics/yolov5', 'custom', path='C:\\Users\\hamiz\\OneDrive\\Desktop\\Car\\yolov5\\runs\\train\\exp\\weights\\best.pt' , force_reload=True)
# Out:
# Downloading: "https://github.com/ultralytics/yolov5/zipball/master" to C:\Users\hamiz/.cache\torch\hub\master.zip
# YOLOv5  2023-11-20 Python-3.10.5 torch-2.1.1+cu121 CPU
#
# Fusing layers...
# Model summary: 157 layers, 7058671 parameters, 0 gradients, 15.9 GFLOPs
# Adding AutoShape...

# %%
# !python /content/yolov5/val.py --img-size 320 --batch-size 16 --data /content/yolov5/data.yaml --weights /content/yolov5/runs/train/exp/weights/best.pt
# Out:
# val: data=/content/yolov5/data.yaml, weights=['/content/yolov5/runs/train/exp/weights/best.pt'], batch_size=16, imgsz=320, conf_thres=0.001, iou_thres=0.6, max_det=300, task=val, device=, workers=8, single_cls=False, augment=False, verbose=False, save_txt=False, save_hybrid=False, save_conf=False, save_json=False, project=yolov5/runs/val, name=exp, exist_ok=False, half=False, dnn=False
# YOLOv5 🚀 2023-11-19 Python-3.10.12 torch-2.1.0+cu118 CUDA:0 (Tesla T4, 15102MiB)
#
# Fusing layers...
# Model summary: 157 layers, 7058671 parameters, 0 gradients, 15.9 GFLOPs
# val: Scanning /content/yolov5/PunjabCarsDataset/data/valid/labels... 49 images, 0 backgrounds, 0 corrupt: 100% 49/49 [00:00<00:00, 770.47it/s]
# val: New cache created: /content/yolov5/PunjabCarsDataset/data/valid/labels.cache
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 4/4 [00:03<00:00,  1.06it/s]
# ...

# %%
pip install opencv-python
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
# WARNING: You are using pip version 22.0.4; however, version 23.3.1 is available.
# You should consider upgrading via the 'C:\Users\hamiz\AppData\Local\Programs\Python\Python310\python.exe -m pip install --upgrade pip' command.

# %%
image_path = 'C:\\Users\\hamiz\\OneDrive\\Desktop\\Car\\yolov5\\PunjabCarsDataset\\data\\test\\images\\DSC_1002.JPG'

# %%
image = cv2.imread(image_path)
image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)

# %%
results = model(image)

# %%
results.print()
# Out:
# image 1/1: 993x1161 1 Not Punjab
# Speed: 115.3ms pre-process, 205.5ms inference, 36.2ms NMS per image at shape (1, 3, 576, 640)

# %%
# %matplotlib inline
plt.imshow(np.squeeze(results.render()))
plt.show()

# %%
image_path = "C:\\Users\\hamiz\\OneDrive\\Desktop\\Car\\yolov5\\PunjabCarsDataset\\data\\test\\images\\DSC_1009.JPG"

# %%
image = cv2.imread(image_path)
image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)

# %%
results = model(image)

# %%
results.print()
# Out:
# image 1/1: 1025x1377 2 Punjabs
# Speed: 50.6ms pre-process, 201.9ms inference, 37.0ms NMS per image at shape (1, 3, 480, 640)

# %%
# %matplotlib inline
plt.imshow(np.squeeze(results.render()))
plt.show()
